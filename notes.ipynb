# %% [markdown]
# ## MySQL is a database management system. A Database Management System (DBMS) is software that interacts with end users, applications, and the database itself to capture and analyze data.

# %%
CREATE DATABASE sql_learning; -- creates a new database named 'sql_learning'

USE DATABASE sql_learning; -- switches to the 'sql_learning' database

CREATE TABLE users (
    id INT PRIMARY KEY AUTO_INCREMENT,
    username VARCHAR(50) NOT NULL,
    email VARCHAR(100) NOT NULL UNIQUE,
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);

SELECT * FROM users;

DROP TABLE users; -- deletes the 'users' table from the database

DROP DATABASE sql_learning; -- deletes the 'sql_learning' database

# %% [markdown]
# 1. Fetch all Duplicate records in a table
#
# Table: USERS
# Note: A Record is called duplicate if a user name is present more than once.
#
# user_id (PK) | user_name | email

# %%
SELECT *,
ROW_NUMBER() OVER (PARTITION BY user_name ORDER BY user_id) AS row_num
